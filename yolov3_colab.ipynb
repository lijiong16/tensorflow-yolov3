# %% [markdown]
# # set up files

# %%
# %cd /content/
# !git clone -b colab https://lijiong16:lijiongshaX.1@github.com/lijiong16/tensorflow-yolov3.git
# Out:
# /content
# Cloning into 'tensorflow-yolov3'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 15430 (delta 8), reused 28 (delta 5), pack-reused 15394
# Receiving objects: 100% (15430/15430), 545.42 MiB | 29.01 MiB/s, done.
# Resolving deltas: 100% (1068/1068), done.
# Checking out files: 100% (8179/8179), done.

# %%
# %cd /content/
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /content
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !mkdir /content/dataset/
# !tar zxvf '/content/drive/My Drive/train.tar.gz' -C /content/dataset >/dev/null 2>&1
# !tar zxvf '/content/drive/My Drive/val.tar.gz' -C /content/dataset >/dev/null 2>&1

# %%
# !mv /content/dataset/train2017 /content/dataset/low_train2017
# !mv /content/dataset/val2017 /content/dataset/low_val2017
#!tar zxvf source-dir dest-dir

# %% [markdown]
# # update code

# %%
# %cd /content/tensorflow-yolov3
# !git pull origin
# Out:
# /content/tensorflow-yolov3
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 1 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), done.
# From https://github.com/lijiong16/tensorflow-yolov3
#    7a53fa7..cb3175d  colab      -> origin/colab
# Updating 7a53fa7..cb3175d
# Fast-forward
#  core/config.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# %cd /content/tensorflow-yolov3
# !python train.py

# %% [markdown]
# # Train from coco

# %%
# %cd /content/tensorflow-yolov3/checkpoint
# !wget https://github.com/YunYang1994/tensorflow-yolov3/releases/download/v1.0/yolov3_coco.tar.gz
# !tar -xvf yolov3_coco.tar.gz

# %%
# %cd /content/tensorflow-yolov3
# !python convert_weight.py --train_from_coco
# !python train.py

# %% [markdown]
# # evaluate

# %%
# %cd /content/tensorflow-yolov3
! python evaluate.py
# %cd mAP
! python main.py -na
# Out:
# /content/tensorflow-yolov3
# WARNING: Logging before flag parsing goes to stderr.
# W0816 02:58:00.117513 139977628321664 deprecation_wrapper.py:119] From evaluate.py:40: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0816 02:58:00.120061 139977628321664 deprecation_wrapper.py:119] From /content/tensorflow-yolov3/core/backbone.py:20: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0816 02:58:00.120518 139977628321664 deprecation_wrapper.py:119] From /content/tensorflow-yolov3/core/common.py:30: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W0816 02:58:00.131552 139977628321664 deprecation.py:323] From /content/tensorflow-yolov3/core/common.py:38: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
# Out:
# /content/tensorflow-yolov3

# %% [markdown]
# # Git push to do?

# %%
# !git remote set-url origin git@github.com:lijiong16/tensorflow-yolov3.git

# %%
# !git config --global user.name "lijiong16"
# !git config --global user.email "lijiong16@github.com"
#cd /content/tensorflow-yolov3            
#!git config --global user.name "lijiong16"
#!git config --global user.email "lijiong16@github.com"


#!git pull --rebase origin colab

# %%
# !git remote set-url origin https://github.com/lijiong16/tensorflow-yolov3.git

# %%
# !git add .|
# !git commit -m '*no print'

# %%
ls
# Out:
# checkpoint/        docs/            LICENSE.fuck  scripts/
# convert_weight.py  evaluate.py*     mAP/          show_result.ipynb
# core/              freeze_graph.py  org.txt       train.py*
# cur.txt            image_demo.py    __pycache__/  video_demo.py
# data/              LICENSE*         README.md*

# %%
# !git remote -v
# Out:
# origin	https://github.com/lijiong16/tensorflow-yolov3.git (fetch)
# origin	https://github.com/lijiong16/tensorflow-yolov3.git (push)
